# %% [markdown]
# # Kuroko: URDF → SDF → USDA (Isaac Lab)
#
# This notebook reproduces the exact URDF used by `kuroko_gazebo.launch.py` for spawning (gazebo:=true),
# then converts it to SDF (mandatory intermediate), normalizes resource URIs, and (optionally) exports USDA.

# %%
import os
from pathlib import Path
import subprocess

# Change these for your workspace
OUTPUT_DIR = Path('/tmp/kuroko_usd_out').resolve()
BASENAME = 'kuroko'

# If running inside a ROS2 overlay, make sure the environment is sourced before starting Jupyter.
print('OUTPUT_DIR:', OUTPUT_DIR)

# %% [markdown]
# ## Run as a ROS2 node
#
# From a sourced ROS2 environment:
#
# ```bash
# ros2 run kuroko_isaac_config_generator usda_generator_node.py \
#   --ros-args -p output_dir:=/tmp/kuroko_usd_out -p run_isaac_export:=false
# ```

# %%
# Or run the helper executable directly after building:
# subprocess.check_call([...])
pass
